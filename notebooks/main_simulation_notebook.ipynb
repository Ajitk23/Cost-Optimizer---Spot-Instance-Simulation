# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %%
from src.visualization import plot_cost_comparison

# %%
cost_data = {
    'instance_type': 'D4_v3',
    'runtime_hours': 5,
    'on_demand_cost': 2.40,
    'spot_cost': 0.85,
    'savings': 1.55
}

# Just show the plot
plot_cost_comparison(cost_data)

# OR Save it also
plot_cost_comparison(cost_data, save_path="../artifacts/plot.png")
# Out:
# 📸 Chart saved to: ../artifacts/plot.png
